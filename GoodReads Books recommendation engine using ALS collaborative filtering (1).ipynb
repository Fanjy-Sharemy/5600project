# %% [markdown]
# ## Building a recommendation engine to recommend books in Spark
#
# Using collaborative filtering to predict ratings of unread books on 'Goodreads'
#
# Warren Buffett was once asked about the key to success, he pointed to a stack of nearby books and said, "Read 500 pages like this every day. That's how knowledge works. It builds up, like compound interest. All of you can do it, but I guarantee not many of you will do it."
# Books are the best resources for most of us to develop and gain perspectives.
#
# I myself love reading books. Once I like a book, I have a habit of going to good books or asking someone who has a similar taste to look for recommendations for the next series of books I might like.
# Artificial Intelligence has made our world so easy by recommending us books, movies, and products all based on the past data that saves our time and energy on analyzing different options. In fact, sometimes machines can recommend us better than what we think because they don't suffer from emotional biases.
#
# **The intuition behind Alternating Least Square**
#
# For someone who loves reading academic papers, here's the link to the paper: https://datajobs.com/data-science-repo/Recommender-Systems-%5BNetflix%5D.pdf.
#
# The most important kind of recommender system is collaborative filtering based approach. Let's say you know a friend who has the same taste as you because you both love psychology, then you might like reading other books that your friend has read but you haven't. This is the sole concept behind collaborative filtering. Now let's talk specifically about Alternating least square method.
#
#
# Collaborative filtering can be easily achieved by matrix factorization techniques like Singular Value decomposition where a user-rating matrix is decomposed into the user-concept matrix, concept-weights matrix, and rating-concept matrix. Concepts are basically latent or hidden factors that the matrix decomposition implicitly generates like in the case of the books, the different concepts can be psychology, data science, philosophy, etc.
#
# Most of the matrix factorization techniques like Singular Value decomposition don't know how to deal with an incomplete/sparse matrix which means having empty values in the user-rating matrix(which is common as not every user would have read all the books). Traditionally, engineers have been imputing those values with the mean or median before performing matrix factorization to do collaborative filtering. This leads to overfitting since the books that have never been rated are being imputed by the mean or median which can skew the results towards them.
#
# Recent methods like Alternating Least square don't suffer from these fallbacks. They suggest modeling directly the observed ratings while avoiding overfitting through a regularized mode

# %%
#import to_read data

file_location = "/FileStore/tables/to_read.csv"
file_type = "csv"

# CSV options
infer_schema = "True"
first_row_is_header = "True"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
to_read = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(to_read)

# Create Temporary Tables
to_read.createOrReplaceTempView("to_read")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>book_id</th></tr></thead><tbody><tr><td>1</td><td>112</td></tr><tr><td>1</td><td>235</td></tr><tr><td>1</td><td>533</td></tr><tr><td>1</td><td>1198</td></tr><tr><td>1</td><td>1874</td></tr><tr><td>1</td><td>2058</td></tr><tr><td>1</td><td>3334</td></tr><tr><td>2</td><td>4</td></tr><tr><td>2</td><td>11</td></tr><tr><td>2</td><td>13</td></tr><tr><td>2</td><td>16</td></tr><tr><td>2</td><td>92</td></tr><tr><td>2</td><td>106</td></tr><tr><td>2</td><td>113</td></tr><tr><td>2</td><td>233</td></tr><tr><td>2</td><td>247</td></tr><tr><td>2</td><td>380</td></tr><tr><td>2</td><td>408</td></tr><tr><td>2</td><td>439</td></tr><tr><td>2</td><td>479</td></tr><tr><td>2</td><td>516</td></tr><tr><td>2</td><td>619</td></tr><tr><td>
td>383</td></tr><tr><td>1952.0</td><td>19</td></tr><tr><td>1999.0</td><td>186</td></tr><tr><td>1981.0</td><td>50</td></tr><tr><td>2011.0</td><td>556</td></tr><tr><td>1975.0</td><td>40</td></tr><tr><td>1989.0</td><td>87</td></tr><tr><td>2002.0</td><td>225</td></tr><tr><td>1958.0</td><td>24</td></tr><tr><td>1962.0</td><td>32</td></tr><tr><td>2006.0</td><td>362</td></tr><tr><td>1961.0</td><td>33</td></tr><tr><td>2004.0</td><td>307</td></tr><tr><td>2013.0</td><td>518</td></tr><tr><td>1955.0</td><td>24</td></tr><tr><td>2012.0</td><td>568</td></tr><tr><td>1972.0</td><td>30</td></tr><tr><td>1991.0</td><td>98</td></tr><tr><td>1983.0</td><td>44</td></tr><tr><td>1977.0</td><td>56</td></tr><tr><td>1974.0</td><td>40</td></tr><tr><td>2014.0</td><td>437</td></tr><tr><td>2015.0</td><td>306</td></tr><tr><td>2005.0</td><td>326</td></tr><tr><td>2003.0</td><td>288</td></tr><tr><td>2016.0</td><td>198</td></tr><tr><td>1971.0</td><td>31</td></tr></tbody></table></div>

# %%
import pandas as pd
import numpy as np
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
books_df.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: (10000, 23)</div>

# %%
3sanity check
books_df = books_df[books_df.ratings_count.str.isdigit() == True]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
books_df.ratings_count = books_df.ratings_count.astype('int')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Top books with most number of ratings on goodbooks

books_df.sort_values(by = 'ratings_count', ascending = False)[['original_title','ratings_count', 'average_rating' ]][0:10]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>original_title</th>
#       <th>ratings_count</th>
#       <th>average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Hunger Games</td>
#       <td>4780653</td>
#       <td>4.34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Harry Potter and the Philosopher's Stone</td>
#       <td>4602479</td>
#       <td>4.44</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Twilight</td>
#       <td>3866839</td>
#       <td>3.57</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>To Kill a Mockingbird</td>
#       <td>3198671</td>
#       <td>4.25</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>The Great Gatsby</td>
#       <td>2683664</td>
#       <td>3.89</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>The Fault in Our Stars</td>
#       <td>2346404</td>
#       <td>4.26</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>The Hobbit or There and Back Again</td>
#       <td>2071616</td>
#       <td>4.25</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>The Catcher in the Rye</td>
#       <td>2044241</td>
#       <td>3.79</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Pride and Prejudice</td>
#       <td>2035490</td>
#       <td>4.24</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Angels &amp; Demons</td>
#       <td>2001311</td>
#       <td>3.85</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
most_ratings = books_df.sort_values(by = 'ratings_count', ascending = False)[['original_title','ratings_count', 'average_rating', 'image_url' ]][0:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Printing top books with most number of ratings**

# %%
import pandas as pd
from IPython.display import Image, HTML
most_ratings['img_html'] = most_ratings['image_url']\
    .str.replace(
        '(.*)', 
        '<img src="\\1" style="max-height:124px;"></img>'
    )
with pd.option_context('display.max_colwidth', 10000):
  
  display(HTML(most_ratings[['original_title', 'img_html', 'ratings_count', 'average_rating' ]].to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>original_title</th>
#       <th>img_html</th>
#       <th>ratings_count</th>
#       <th>average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Hunger Games</td>
#       <td><img src="https://images.gr-assets.com/books/1447303603m/2767052.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>4780653</td>
#       <td>4.34</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>
th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3627</th>
#       <td>The Complete Calvin and Hobbes</td>
#       <td>28900</td>
#       <td>4.82</td>
#     </tr>
#     <tr>
#       <th>861</th>
#       <td>Words of Radiance</td>
#       <td>73572</td>
#       <td>4.77</td>
#     </tr>
#     <tr>
#       <th>3274</th>
#       <td>None</td>
#       <td>33220</td>
#       <td>4.77</td>
#     </tr>
#     <tr>
#       <th>8853</th>
#       <td>Mark of the Lion Trilogy</td>
#       <td>9081</td>
#       <td>4.76</td>
#     </tr>
#     <tr>
#       <th>7946</th>
#       <td>None</td>
#       <td>8953</td>
#       <td>4.76</td>
#     </tr>
#     <tr>
#       <th>4482</th>
#       <td>It's a Magical World: A Calvin and Hobbes Coll...</td>
#       <td>22351</td>
#       <td>4.75</td>
#     </tr>
#     <tr>
#       <th>6360</th>
#       <td>There's Treasure Everywhere: A Calvin and Hobb...</td>
#       <td>16766</td>
#       <td>4.74</td>
#     </tr>
#     <tr>
#       <th>421</th>
#       <td>Complete Harry Potter Boxed Set</td>
#       <td>190050</td>
#       <td>4.74</td>
#     </tr>
#     <tr>
#       <th>6589</th>
#       <td>The Authoritative Calvin and Hobbes</td>
#       <td>16087</td>
#       <td>4.73</td>
#     </tr>
#     <tr>
#       <th>6919</th>
#       <td>The Indispensable Calvin and Hobbes: A Calvin ...</td>
#       <td>14597</td>
#       <td>4.73</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
high_rating_books = books_df.sort_values(by = 'average_rating', ascending = False)[['original_title','ratings_count','image_url', 'average_rating' ]][0:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Printing top books with highest average ratings**

# %%
high_rating_books['img_html'] = high_rating_books['image_url']\
    .str.replace(
        '(.*)', 
        '<img src="\\1" style="max-height:124px;"></img>'
    )
with pd.option_context('display.max_colwidth', 10000):
  
  display(HTML(high_rating_books[['original_title', 'img_html','ratings_count', 'average_rating' ]].to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>original_title</th>
#       <th>img_html</th>
#       <th>ratings_count</th>
#       <th>average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3627</th>
#       <td>The Complete Calvin and Hobbes</td>
#       <td><img src="https://images.gr-assets.com/books/1473064526m/24812.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>28900</td>
#       <td>4.82</td>
#     </tr>
#     <tr>
#       <th>861</th>
#       <td>Words of Radiance</td>
#       <td><img src="https://images.gr-assets.com/books/1391535251m/17332218.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>73572</td>
#       <td>4.77</td>
#     </tr>
#     <tr>
#       <th>3274</th>
#       <td>None</td>
#       <td><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>33220</td>
#       <td>4.77</td>
#     </tr>
#     <tr>
#       <th>8853</th>
#       <td>Mark of the Lion Trilogy</td>
#       <td><img src="https://images.gr-assets.com/books/1349032180m/95602.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>9081</td>
#       <td>4.76</td>
#     </tr>
#     <tr>
#       <th>7946</th>
#       <td>None</td>
#       <td><img src="https://images.gr-assets.com/books/1410151002m/5031805.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>8953</td>
#       <td>4.76</td>
#     </tr>
#     <tr>
#       <th>4482</th>
#       <td>It's a Magical World: A Calvin and Hobbes Collection</td>
#       <td><img src="https://images.gr-assets.com/books/1437420710m/24814.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>22351</td>
#       <td>4.75</td>
#     </tr>
#     <tr>
#       <th>6360</th>
#       <td>There's Treasure Everywhere: A Calvin and Hobbes Collection</td>
#       <td><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>16766</td>
#       <td>4.74</td>
#     </tr>
#     <tr>
#       <th>421</th>
#       <td>Complete Harry Potter Boxed Set</td>
#       <td><img src="https://images.gr-assets.com/books/1392579059m/862041.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>190050</td>
#       <td>4.74</td>
#     </tr>
#     <tr>
#       <th>6589</th>
#       <td>The Authoritative Calvin and Hobbes</td>
#       <td><img src="https://images.gr-assets.com/books/1391114055m/59715.jpg" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>16087</td>
#       <td>4.73</td>
#     </tr>
#     <tr>
#       <th>6919</th>
#       <td>The Indispensable Calvin and Hobbes: A Calvin and Hobbes Treasury</td>
#       <td><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" style="max-height:124px;"></img><img src="" style="max-height:124px;"></img></td>
#       <td>14597</td>
#       <td>4.73</td>
#     </tr>
#   </tbody>
# </table>

# %%
authors_with_most_books = pd.DataFrame(books_df.authors.value_counts()[0:10]).reset_index()
authors_with_most_books.columns = ['author', 'number_of_books']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
 authors_with_most_books
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>author</th>
#       <th>number_of_books</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Stephen King</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Nora Roberts</td>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dean Koontz</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Terry Pratchett</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Agatha Christie</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Meg Cabot</td>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>James Patterson</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>David Baldacci</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>John Grisham</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>J.D. Robb</td>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.title('Distribution of Average Ratings')
books_df['average_rating'].hist()
display()

# %%
ratings.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------+
# book_id|user_id|rating|
# +-------+-------+------+
#       1|    314|     5|
#       1|    439|     3|
#       1|    588|     5|
#       1|   1169|     4|
#       1|   1185|     4|
# +-------+-------+------+
# only showing top 5 rows
#
# </div>

# %%
#1 million ratings

ratings.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----------------+------------------+------------------+
# summary|          book_id|           user_id|            rating|
# +-------+-----------------+------------------+------------------+
#   count|           981756|            981756|            981756|
#    mean|4943.275635697668|25616.759933221696|3.8565335989797873|
#  stddev|2873.207414896143|15228.338825882149|0.9839408559619973|
#     min|                1|                 1|                 1|
#     max|            10000|             53424|                 5|
# +-------+-----------------+------------------+------------------+
#
# </div>

# %%
#Each book has 100 ratings in the ratingss dataframe

ratings.groupby('book_id').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-
>9777</td><td>98</td></tr><tr><td>Path of the Assassin</td><td>7520</td><td>99</td></tr><tr><td>Xenocide</td><td>8648</td><td>94</td></tr><tr><td>Saving Fish from Drowning: A Novel</td><td>9503</td><td>97</td></tr><tr><td>Prep</td><td>9844</td><td>93</td></tr><tr><td>The Tragedy of Macbeth</td><td>8852</td><td>99</td></tr><tr><td>Less Than Zero</td><td>9915</td><td>90</td></tr><tr><td>The Informers</td><td>9914</td><td>94</td></tr><tr><td>Last Orders</td><td>5068</td><td>98</td></tr><tr><td>Even Cowgirls Get the Blues</td><td>7572</td><td>99</td></tr><tr><td>I Feel Bad About My Neck: And Other Thoughts on Being a Woman</td><td>8765</td><td>97</td></tr><tr><td>Sons of Destiny (Cirque Du Freak, Book 12)</td><td>8948</td><td>61</td></tr><tr><td>Another Roadside Attraction</td><td>9570</td><td>83</td></tr><tr><td>As The Crow Flies</td><td>7201</td><td>97</td></tr><tr><td>Freak the Mighty</td><td>8953</td><td>97</td></tr><tr><td>Witches Abroad</td><td>2442</td><td>98</td></tr><tr><td>A Woman of Substance </td><td>8155</td><td>99</td></tr><tr><td>The Atonement Child</td><td>9943</td><td>89</td></tr><tr><td>Rachel's Holiday</td><td>9301</td><td>78</td></tr><tr><td>Ghostwritten</td><td>6819</td><td>60</td></tr><tr><td>The Idiot Girls' Action-Adventure Club: True Tales from a Magnificent and Clumsy Life</td><td>7531</td><td>99</td></tr><tr><td>Marlfox</td><td>7999</td><td>98</td></tr><tr><td>The Bourne Identity</td><td>786 ...

# %%
ratings = ratings.select(ratings.user_id,
                         ratings.book_id,
                         ratings.rating.cast("double"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ratings.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------+
# user_id|book_id|rating|
# +-------+-------+------+
#     314|      1|   5.0|
#     439|      1|   3.0|
#     588|      1|   5.0|
#    1169|      1|   4.0|
#    1185|      1|   4.0|
# +-------+-------+------+
# only showing top 5 rows
#
# </div>

# %%
# Count the total number of ratings in the dataset
numerator = ratings.select("rating").count()

# Count the number of distinct Id's
num_users = ratings.select("user_id").distinct().count()
num_items = ratings.select("book_id").distinct().count()

# Set the denominator equal to the number of users multiplied by the number of items
denominator = num_users * num_items

# Divide the numerator by the denominator
sparsity = (1.0 - (numerator * 1.0)/ denominator) * 100
print("The ratings dataframe is ", "%.2f" % sparsity + "% empty.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The ratings dataframe is  99.82% empty.
# </div>

# %%
# Min num ratings 
print("Item with the fewest ratings: ")
ratings.groupBy("book_id").count().sort('count').show(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Item with the fewest ratings:
# +-------+-----+
# book_id|count|
# +-------+-----+
#    7803|    8|
#    9345|   11|
#    9486|   24|
#    1935|   34|
#    9315|   36|
#    9553|   41|
#    8181|   44|
#    9260|   46|
#    9479|   47|
#    9705|   48|
# +-------+-----+
# only showing top 10 rows
#
# </div>

# %%
# Group data by user_id, count ratings
(ratings.groupBy("user_id")
    .count()
    .filter("`count` >= 5")
    .orderBy('count', ascending=False)
    .show(n = 10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# user_id|count|
# +-------+-----+
#   12874|  200|
#   30944|  200|
#   28158|  199|
#   12381|  199|
#   52036|  199|
#    6630|  197|
#   37834|  197|
#   45554|  197|
#   24143|  196|
#    9668|  196|
# +-------+-----+
# only showing top 10 rows
#
# </div>

# %%
(ratings.groupBy("book_id")
    .count()
    .filter("`count` > 1")
    .orderBy('count', ascending=False)
    .show(n = 10))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# book_id|count|
# +-------+-----+
#      31|  100|
#     516|  100|
#    1139|  100|
#    1143|  100|
#    1270|  100|
#    1303|  100|
#    1322|  100|
#    1339|  100|
#    1352|  100|
#    1618|  100|
# +-------+-----+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# **Now, let's split the data into training and test set to use collaborative filtering usingn Alternate Least Square method**

# %%
(training, test) = ratings.randomSplit([0.8, 0.2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------+
# user_id|book_id|rating|
# +-------+-------+------+
#       7|   1646|   3.0|
#       7|   2045|   3.0|
#       7|   2129|   5.0|
#       7|   2189|   3.0|
#       7|   2325|   4.0|
# +-------+-------+------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# **Let's import ALS and regression evaluator to find RMSE.**

# %%
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.sql import Row
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
als = ALS( userCol="user_id", itemCol="book_id", ratingCol="rating",
          coldStartStrategy="drop", nonnegative = True, implicitPrefs = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **'implicitPrefs ' argument is used when we are not using explicit data like the rating data here. Sometimes companies don't have explicit data like ratings and still want to build a recommendation engine using other proxies like views, clicks, wishlists, etc. **
#
# **In that case, implicit preference is used but is out of the scope of our good books project. 'coldStartStrategy ' is used when we don't have any data for a user which might lead to null prediction if the user on the test set has no rating in the training set. We have dropped the cold start strategy because we want to avoid such situations for our problem in hand.**
#
#
# **Now let's build our hyperparameter list and then fit the algorithm on the training data.**

# %%
type(als)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: pyspark.ml.recommendation.ALS</div>

# %%
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator 

param_grid = ParamGridBuilder() \
            .addGrid(als.rank, [10, 50, 75, 100]) \
            .addGrid(als.maxIter, [5, 50, 75, 100]) \
            .addGrid(als.regParam, [.01, .05, .1, .15]) \
            .build()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Num models to be tested using param_grid: 64
# There is a total of 64 models that will be tested and tuned before we receive the final model. The power of parallelization and spark will make it pretty fast though.**

# %%
# Define evaluator as RMSE
evaluator = RegressionEvaluator(metricName = "rmse", 
                                labelCol = "rating", 
                                predictionCol = "prediction")
# Print length of evaluator
print ("Num models to be tested using param_grid: ", len(param_grid))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Num models to be tested using param_grid:  64
# </div>

# %%
# Build cross validation using CrossValidator
cv = CrossValidator(estimator = als, 
                    estimatorParamMaps = param_grid, 
                    evaluator = evaluator, 
                    numFolds = 5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(cv)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">CrossValidator_089d3e0e8add
# </div>

# %%
model = als.fit(training)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions = model.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predictions.show(n = 10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+------+----------+
# user_id|book_id|rating|prediction|
# +-------+-------+------+----------+
#    3922|    148|   3.0| 3.7151182|
#   32055|    148|   3.0| 3.1291625|
#   27834|    148|   3.0|  3.832256|
#   13407|    148|   4.0| 3.9250367|
#   29703|    148|   4.0| 3.7403727|
#   40167|    148|   5.0| 3.2674868|
#   46139|    148|   5.0| 3.8008392|
#   17228|    148|   5.0| 3.9937172|
#   14372|    148|   3.0|  3.188208|
#   30681|    148|   2.0| 3.1382155|
# +-------+-------+------+----------+
# only showing top 10 rows
#
# </div>

# %% [markdown]
# **Well, the prediction on the test set shows that it is very close to the original rating. Like for example the rating for user_id 14372 was originally 3 and our algorithm predicted it to be 3.13 which is pretty close.**

# %%
predictions.createOrReplaceTempView("predictions")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from predictions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>book_id</th><th>rating</th><th>prediction</th></tr></thead><tbody><tr><td>3922</td><td>148</td><td>3.0</td><td>3.7151182</td></tr><tr><td>32055</td><td>148</td><td>3.0</td><td>3.1291625</td></tr><tr><td>27834</td><td>148</td><td>3.0</td><td>3.832256</td></tr><tr><td>13407</td><td>148</td><td>4.0</td><td>3.9250367</td></tr><tr><td>29703</td><td>148</td><td>4.0</td><td>3.7403727</td></tr><tr><td>40167</td><td>148</td><td>5.0</td><td>3.2674868</td></tr><tr><td>46139</td><td>148</td><td>5.0</td><td>3.8008392</td></tr><tr><td>17228</td><td>148</td><td>5.0</td><td>3.9937172</td></tr><tr><td>14372</td><td>148</td><td>3.0</td><td>3.188208</td></tr><tr><td>30681</td><td>148</td><td>2.0</td><td>3.1382155</td></tr><tr><td>10944</td><td>148</td><td>4.0</td><td>3.747405</td></tr><tr><td>11945</td><td>148</td><td>4.0</td><td>3.9951036</td></tr><tr><td>45811</td><td>148</td><td>3.0</td><td>3.7638686</td></tr><tr><td>6689</td><td>463</td><td>4.0</td><td>3.353484</td></tr><tr><td>5152</td><td>463</td><td>4.0</td><td>4.221477</td></tr><tr><td>41145</td><td>463</td><td>4.0</td><td>4.0171585</td></tr><tr><td>1294</td><td>463</td><td>4.0</td><td>3.928851</td></tr><tr><td>12806</td><td>463</td><td>3.0</td><td>4.162929</td></tr><tr><td>52012</td><td>463</td><td>5.0</td><td>3.359523</td></tr><tr><td>8043</td><td>463</td><td>4.0</td><td>3.9729245</td></tr><tr><td>16081</td><td>463</td><td>4.0</td><td>4.649987</td></tr><tr><td>50999</td><td>463</td><td>5.0</td><td>4.61083</td></tr><tr><td>48493</td><td>463</td><td>5.0</td><td>4.3947697</td></tr><tr><td>1947</td><td>463</td><td>4.0</td><td>4.133591</td></tr><tr><td>11191</td><td>463</td><td>5.0</td><td>4.740238</td></tr><tr><td>22154</td><td>463</td><td>3.0</td><td>3.5734375</td></tr><tr><td>28540</td><td>463</td><td>5.0</td><td>4.7005625</td></tr><tr><td>2271</td><td>463</td><td>3.0</td><td>3.535572</td></tr><tr><td>9195</td><td>463</td><td>3.0</td><td>3.3095796</td></tr><tr><td>11502</td><td>463</td><td>2.0</td><td>3.472526</td></tr><tr><td>26146</td><td>463</td><td>5.0</td><td>4.6619616</td></tr><tr><td>14599</td><td>463</td><td>4.0</td><td>4.827334</td></tr><tr><td>52334</td><td>463</td><td
# %%
rmse = evaluator.evaluate(predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root-mean-square error = 0.9136908117752192
# </div>

# %% [markdown]
# **Root-mean-square error = 0.913, On average the mean error is .9 that is the difference between the original rating and the predicted rating. Now, let's predict 10 books and ratings for each user.**

# %%
# Generate n recommendations for all users
ALS_recommendations = model.recommendForAllUsers(numItems = 10) # n - 10
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ALS_recommendations.show(n = 10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+
# user_id|     recommendations|
# +-------+--------------------+
#     148|[[4778, 4.4863176...|
#     463|[[2627, 5.0448065...|
#     471|[[1338, 4.017694]...|
#     496|[[1338, 5.923006]...|
#     833|[[9942, 5.1651993...|
#    1088|[[9531, 4.937608]...|
#    1342|[[7789, 5.308443]...|
#    1580|[[4868, 5.307861]...|
#    1591|[[6413, 4.853365]...|
#    1645|[[9252, 4.545126]...|
# +-------+--------------------+
# only showing top 10 rows
#
# </div>

# %%
# Temporary table
ALS_recommendations.registerTempTable("ALS_recs_temp")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
clean_recs = spark.sql("""SELECT user_id,
                            movieIds_and_ratings.book_id AS book_id,
                            movieIds_and_ratings.rating AS prediction
                        FROM ALS_recs_temp
                        LATERAL VIEW explode(recommendations) exploded_table
                            AS movieIds_and_ratings""")
clean_recs.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+----------+
# user_id|book_id|prediction|
# +-------+-------+----------+
#     148|   4778| 4.4863176|
#     148|   9842|  4.447763|
#     148|   8233|   4.43292|
#     148|   6590|  4.427131|
#     148|   6435| 4.4253044|
#     148|   3520| 4.3928666|
#     148|   1451| 4.3633265|
#     148|   8946| 4.3481536|
#     148|   2865|  4.333218|
#     148|   6226|  4.327692|
#     463|   2627| 5.0448065|
#     463|    641|  4.920231|
#     463|   4344|  4.757169|
#     463|    347|  4.736475|
#     463|   3331| 4.7246222|
#     463|   6784| 4.7192845|
#     463|   6032|  4.706223|
#     463|    332| 4.6923423|
#     463|   4201|  4.677836|
#     463|   8729| 4.6729965|
# +-------+-------+----------+
# only showing top 20 rows
#
# </div>

# %%
# Recommendations for unread books
(clean_recs.join(ratings, ["user_id", "book_id"], "left")
    .filter(ratings.rating.isNull()).show())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+----------+------+
# user_id|book_id|prediction|rating|
# +-------+-------+----------+------+
#      22|   7547|  4.304169|  null|
#      27|   1198|   4.91851|  null|
#      32|   8362| 4.9440556|  null|
#      63|   3753| 4.6486487|  null|
#      85|   2652| 3.3583734|  null|
#     102|   9790| 2.9214456|  null|
#     103|   6590|  4.182767|  null|
#     150|   2940| 3.9354944|  null|
#     163|   8435|  4.819208|  null|
#     178|   6876| 4.6961846|  null|
#     200|   7550| 4.1670904|  null|
#     235|   7593| 3.6903093|  null|
#     244|   5335| 3.9928238|  null|
#     268|   6963| 5.2813425|  null|
#     277|   9570| 4.4697027|  null|
#     284|   7401|  4.905814|  null|
#     297|   6312| 4.4401374|  null|
#     298|    296| 4.9835024|  null|
#     320|   4441| 5.3855753|  null|
#     325|   6089| 5.4266243|  null|
# +-------+-------+----------+------+
# only showing top 20 rows
#
# </div>

# %%
new_books = (clean_recs.join(ratings, ["user_id", "book_id"], "left")
    .filter(ratings.rating.isNull()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(new_books.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">522033
# </div>

# %%
new_books.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+----------+------+
# user_id|book_id|prediction|rating|
# +-------+-------+----------+------+
#      22|   7547|  4.304169|  null|
#      27|   1198|   4.91851|  null|
#      32|   8362| 4.9440556|  null|
#      63|   3753| 4.6486487|  null|
#      85|   2652| 3.3583734|  null|
# +-------+-------+----------+------+
# only showing top 5 rows
#
# </div>

# %%
to_read.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+
# user_id|book_id|
# +-------+-------+
#       1|    112|
#       1|    235|
#       1|    533|
#       1|   1198|
#       1|   1874|
# +-------+-------+
# only showing top 5 rows
#
# </div>

# %%
# Create Temporary Tables
new_books.createOrReplaceTempView("new_books")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(new_books.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">522033
# </div>

# %%
print(to_read.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">912705
# </div>

# %%
# Create Temporary Tables
to_read.createOrReplaceTempView("to_read")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
recommendations = new_books.join(to_read,
                              on = ["user_id", "book_id"], 
                              how = "inner")
print(recommendations.show())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+----------+------+
# user_id|book_id|prediction|rating|
# +-------+-------+----------+------+
#    1266|   2840|   4.29498|  null|
#   22372|   7529| 4.0330534|  null|
#   38364|   3294|  4.050369|  null|
#   45435|   3849|   4.86768|  null|
#   11321|   8187|  4.010494|  null|
#   26207|   1618| 4.3792477|  null|
#   42077|   2700| 4.8624945|  null|
#    1394|   3885| 4.5378723|  null|
#   21924|   6425| 5.3291073|  null|
#   31839|    862|  5.177144|  null|
#   40970|   5607| 4.0587697|  null|
#   43735|    192|  5.316787|  null|
#    6713|   3124|  4.092127|  null|
#   44066|   1198| 4.1666613|  null|
#   16329|   2334|  4.752753|  null|
#   22982|   3243| 4.7963924|  null|
#   37489|   5881| 5.3499827|  null|
#   42874|   6384|  4.566016|  null|
#   19783|   6963|  4.308795|  null|
#   33003|   7670| 4.9878936|  null|
# +-------+-------+----------+------+
# only showing top 20 rows
#
# None
# </div>

# %%
print(recommendations.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">857
# </div>

# %%
(recommendations
     .withColumn('pred_trunc', recommendations.prediction.substr(1,1))
     .groupby('pred_trunc')
     .count()
     .sort('pred_trunc')
    .show())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+
# pred_trunc|count|
# +----------+-----+
#          0|    2|
#          1|    5|
#          2|   14|
#          3|  113|
#          4|  459|
#          5|  260|
#          6|    4|
# +----------+-----+
#
# </div>

# %%
# Create Temporary Tables
recommendations.createOrReplaceTempView("recommendations")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.title('Most of the predicted ratings are above 3.8', fontsize = 12)
plt.suptitle('Distribution of predictedd ratings for the to_do lists', fontsize = 18)
rec = recommendations.toPandas()
rec['prediction'].hist()
display()

# %% [markdown]
# **Most of the books in the wishlist are predicted as 4.5 or more which is expected.**
